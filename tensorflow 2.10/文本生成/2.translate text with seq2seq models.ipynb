# %%
import numpy as np
import einops
import tensorflow as tf
import tensorflow_text as tf_text
import tensorflow as tf
gpu_list = tf.config.experimental.list_physical_devices('GPU')
if len(gpu_list) > 0:
    for gpu in gpu_list:
        try:
            tf.config.experimental.set_memory_growth(gpu, True)
        except RuntimeError as e:
            print(e) 
else:
    print("Got no gpus")
# Out:
# D:\anaconda\envs\tf-gpu-2.10.0-py-3.10\lib\site-packages\numpy\_distributor_init.py:30: UserWarning: loaded more than 1 DLL from .libs:
# D:\anaconda\envs\tf-gpu-2.10.0-py-3.10\lib\site-packages\numpy\.libs\libopenblas.FB5AE2TYXYH2IJRDKGDGQ3XBKLKTF43H.gfortran-win_amd64.dll
# D:\anaconda\envs\tf-gpu-2.10.0-py-3.10\lib\site-packages\numpy\.libs\libopenblas64__v0.3.23-246-g3d31191b-gcc_10_3_0.dll
#   warnings.warn("loaded more than 1 DLL from .libs:"

# %%
import pathlib

path_to_zip = tf.keras.utils.get_file( 'spa-eng.zip', origin='http://storage.googleapis.com/download.tensorflow.org/data/spa-eng.zip',extract=True)
path_to_file = pathlib.Path(path_to_zip).parent/'spa-eng/spa.txt'
def load_data(path):
    text = path.read_text(encoding='utf-8')
    lines = text.splitlines()
    pairs = [line.split('\t') for line in lines]
    context = np.array([context for target, context in pairs])
    target = np.array([target for target, context in pairs])
    return target, context
target_raw, context_raw = load_data(path_to_file)
print(len(target_raw) == len(context_raw))
print(target_raw[-1],"||",context_raw[-1])
# Out:
# True
# If you want to sound like a native speaker, you must be willing to practice saying the same sentence over and over in the same way that banjo players practice the same phrase over and over until they can play it correctly and at the desired tempo. || Si quieres sonar como un hablante nativo, debes estar dispuesto a practicar diciendo la misma frase una y otra vez de la misma manera en que un músico de banjo practica el mismo fraseo una y otra vez hasta que lo puedan tocar correctamente y en el tiempo esperado.

# %%
BUFFER_SIZE = len(context_raw)
BATCH_SIZE = 64
is_train = np.random.uniform(size=(BUFFER_SIZE,)) < 0.8
train_raw = tf.data.Dataset.from_tensor_slices((context_raw[is_train], target_raw[is_train])).shuffle(BUFFER_SIZE).batch(BATCH_SIZE)
val_raw = tf.data.Dataset.from_tensor_slices((context_raw[~is_train], target_raw[~is_train])).shuffle(BUFFER_SIZE).batch(BATCH_SIZE)
for example_context_strings, example_target_strings in train_raw.take(1):
    print(example_context_strings[:5])
    print(example_target_strings[:5])
# Out:
# tf.Tensor(
# [b'\xc3\x89l explic\xc3\xb3 c\xc3\xb3mo hacer un fuego.'
#  b'\xc2\xbfSpot tambi\xc3\xa9n fue?'
#  b'\xc2\xbfEste muro se construy\xc3\xb3 para mantener a la gente fuera o para mantenerla dentro?'
#  b'\xc2\xbfLe duele el est\xc3\xb3mago?'
#  b'Tom est\xc3\xa1 muy ocupado en este momento.'], shape=(5,), dtype=string)
# tf.Tensor(
# [b'He explained how to make a fire.' b'Did Spot go, too?'
#  b'Was this wall built to keep people out or to keep them in?'
#  b'Do you have a stomachache?' b'Tom is very busy right now.'], shape=(5,), dtype=string)

# %%
def tf_lower_and_split_punct(text):
    text = tf_text.normalize_utf8(text, 'NFKD')
    text = tf.strings.lower(text)
    text = tf.strings.regex_replace(text, '[^ a-z.?!,¿]', '')
    text = tf.strings.regex_replace(text, '[.?!,¿]', r' \0 ')
    text = tf.strings.strip(text)
    text = tf.strings.join(['[START]', text, '[END]'], separator=' ')
    return text

max_vocab_size = 5000
context_text_processor = tf.keras.layers.TextVectorization(standardize=tf_lower_and_split_punct, max_tokens=max_vocab_size, ragged=True)
context_text_processor.adapt(train_raw.map(lambda context, target:context))

target_text_processor = tf.keras.layers.TextVectorization(standardize=tf_lower_and_split_punct, max_tokens=max_vocab_size, ragged=True)
target_text_processor.adapt(train_raw.map(lambda context, target:target))

# %%
def process_text(context, target):
    context = context_text_processor(context).to_tensor()
    target = target_text_processor(target)
    target_in = target[:, :-1].to_tensor()
    target_ou = target[:, 1:].to_tensor()
    return (context, target_in), target_ou

train_ds = train_raw.map(process_text,  tf.data.AUTOTUNE)
val_ds = val_raw.map(process_text, tf.data.AUTOTUNE)

for (A,B),C in train_ds.take(1):
    print(A[0, :10])
    print(B[0, :10])
    print(C[0, :10])
# Out:
# tf.Tensor([   2  311    5   22 3312    4    3    0    0    0], shape=(10,), dtype=int64)
# tf.Tensor([  2   6 120  16   6  79  96  44   4   0], shape=(10,), dtype=int64)
# tf.Tensor([  6 120  16   6  79  96  44   4   3   0], shape=(10,), dtype=int64)

# %%
UNITS = 516
class Encoder(tf.keras.layers.Layer):
    def __init__(self, text_processor, units):
        super(Encoder, self).__init__()
        self.text_processor = text_processor
        self.vocab_size = text_processor.vocabulary_size()
        self.units = units
        self.embedding = tf.keras.layers.Embedding(self.vocab_size, units, mask_zero=True)
        self.rnn = tf.keras.layers.Bidirectional(merge_mode='sum', layer=tf.keras.layers.GRU(units, return_sequences=True, recurrent_initializer='glorot_uniform'))
    
    def call(self, x):
        x = self.embedding(x)
        x = self.rnn(x)
        return x
    
    def convert_input(self, texts):
        texts = tf.convert_to_tensor(texts)
        if len(texts.shape) == 0:
            texts = tf.convert_to_tensor(texts)[tf.newaxis]
        context = self.text_processor(texts).to_tensor()
        context = self(context)
        return context

# %%
class CrossAttention(tf.keras.layers.Layer):
    def __init__(self, units, **kwargs):
        super().__init__()
        self.mha = tf.keras.layers.MultiHeadAttention(key_dim=units, num_heads=5, **kwargs)
        self.layernorm = tf.keras.layers.LayerNormalization()
        self.add = tf.keras.layers.Add()

    def call(self, x, context):
        attn_ouput, attn_scores = self.mha(query=x, value=context, return_attention_scores=True)
        attn_scores = tf.reduce_mean(attn_scores, axis=1)
        self.last_attention_weights = attn_scores
        x = self.add([x, attn_ouput])
        x = self.layernorm(x)
        return x

# %%
# target_text_processor.get_vocabulary()
# tf.keras.layers.StringLookup(vocabulary=target_text_processor.get_vocabulary()).get_vocabulary()
# Out:
# ['[UNK]',
#  '',
#  '[UNK]',
#  '[START]',
#  '[END]',
#  '.',
#  'the',
#  'i',
#  'to',
#  'you',
#  'tom',
#  'a',
#  '?',
#  'is',
#  'he',
#  'in',
#  'of',
#  'that',
#  'it',
#  'was',
#  ',',
#  'do',
#  'have',
#  'this',
#  'me',
#  'my',
#  'for',
#  'she',
#  'dont',
#  'are',
#  'what',
#  'his',
#  'mary',
#  'we',
#  'your',
#  'on',
#  'be',
#  'with',
#  'want',
#  'not',
#  'im',
#  'and',
#  'like',
#  'at',
#  'know',
#  'him',
#  'can',
#  'go',
#  'her',
#  'has',
#  'will',
#  'its',
#  'they',
#  'there',
#  'time',
#  'how',
#  'were',
#  'did',
#  'very',
#  'as',
#  'had',
#  'all',
#  'here',
#  'about',
#  'up',
#  'didnt',
#  'think',
#  'out',
#  'get',
#  'when',
#  'from',
#  'if',
#  'cant',
#  'an',
#  'no',
#  'one',
#  'going',
#  'doesnt',
#  'by',
#  'why',
#  'would',
#  'see',
#  'come',
#  'good',
#  'ill',
#  'please',
#  'youre',
#  'who',
#  'been',
#  'just',
#  'need',
#  'so',
#  'more',
#  'than',
#  'where',
#  'tell',
#  'now',
#  'help',
#  'never',
#  'but',
#  'too',
#  'got',
#  'some',
#  'am',
#  'something',
#  'us',
#  'take',
#  'last',
#  'ive',
#  'should',
#  'day',
#  'much',
#  'car',
#  'money',
#  'could',
#  'work',
#  'people',
#  'home',
#  'well',
#  'back',
#  'really',
#  'said',
#  'told',
#  '!',
#  'our',
#  'many',
#  'went',
#  'lot',
#  'book',
#  'house',
#  'any',
#  'anything',
#  'eat',
#  'isnt',
#  'hes',
#  'french',
#  'make',
#  'thought',
#  'say',
#  'only',
#  'does',
#  'school',
#  'room',
#  'made',
#  'new',
#  'two',
#  'thats',
#  'must',
#  'toms',
#  'give',
#  'long',
#  'right',
#  'speak',
#  'always',
#  'every',
#  'today',
#  'man',
#  'old',
#  'love',
#  'three',
#  'lets',
#  'father',
#  'wanted',
#  'look',
#  'let',
#  'before',
#  'still',
#  'off',
#  'night',
#  'asked',
#  'boston',
#  'left',
#  'talk',
#  'id',
#  'tomorrow',
#  'leave',
#  'little',
#  'again',
#  'saw',
#  'nothing',
#  'way',
#  'put',
#  'dog',
#  'after',
#  'or',
#  'job',
#  'yesterday',
#  'whats',
#  'over',
#  'into',
#  'years',
#  'down',
#  'live',
#  'better',
#  'may',
#  'them',
#  'everything',
#  'english',
#  'happy',
#  'buy',
#  'stay',
#  'came',
#  'wont',
#  'read',
#  'wants',
#  'theres',
#  'first',
#  'find',
#  'couldnt',
#  'play',
#  'next',
#  'took',
#  'other',
#  'mother',
#  'understand',
#  'life',
#  'children',
#  'these',
#  'ask',
#  'keep',
#  'friends',
#  'feel',
#  'believe',
#  'bought',
#  'door',
#  'morning',
#  'doing',
#  'stop',
#  'lost',
#  'problem',
#  'late',
#  'their',
#  'call',
#  'ever',
#  'away',
#  'used',
#  'soon',
#  'name',
#  'gave',
#  'friend',
#  'sure',
#  'already',
#  'happened',
#  'enough',
#  'alone',
#  'remember',
#  'wrong',
#  'without',
#  'bad',
#  'boy',
#  'wasnt',
#  'hard',
#  'even',
#  'year',
#  'water',
#  'married',
#  'found',
#  'teacher',
#  'heard',
#  'best',
#  'try',
#  'marys',
#  'busy',
#  'same',
#  'bed',
#  'week',
#  'looks',
#  'things',
#  'wait',
#  'seen',
#  'looking',
#  'often',
#  'done',
#  'beautiful',
#  'because',
#  'knows',
#  'able',
#  'knew',
#  'hear',
#  'party',
#  'likes',
#  'tired',
#  'cold',
#  'thing',
#  'john',
#  'idea',
#  'food',
#  'train',
#  'big',
#  'theyre',
#  'answer',
#  'while',
#  'coffee',
#  'true',
#  'person',
#  'drink',
#  'being',
#  'hope',
#  'use',
#  'everyone',
#  'around',
#  'watch',
#  'letter',
#  'learn',
#  'shes',
#  'brother',
#  'books',
#  'yet',
#  'mind',
#  'wish',
#  'met',
#  'died',
#  'seems',
#  'which',
#  'open',
#  'japan',
#  'girl',
#  'study',
#  'days',
#  'youll',
#  'someone',
#  'talking',
#  'almost',
#  'world',
#  'young',
#  'turn',
#  'truth',
#  'parents',
#  'each',
#  'another',
#  'sleep',
#  'pay',
#  'lunch',
#  'bus',
#  'walk',
#  'place',
#  'care',
#  'tried',
#  'getting',
#  'those',
#  'kind',
#  'anyone',
#  'looked',
#  'family',
#  'own',
#  'afraid',
#  'few',
#  'monday',
#  'both',
#  'most',
#  'together',
#  'havent',
#  'early',
#  'rain',
#  'happen',
#  'once',
#  'great',
#  'until',
#  'plan',
#  'write',
#  'ten',
#  'difficult',
#  'tv',
#  'sister',
#  'mine',
#  'doctor',
#  'angry',
#  'show',
#  'wouldnt',
#  'else',
#  'since',
#  'hours',
#  'dinner',
#  'cat',
#  'yourself',
#  'favorite',
#  'ago',
#  'meeting',
#  'start',
#  'himself',
#  'country',
#  'youve',
#  'wife',
#  'says',
#  'everybody',
#  'child',
#  'hurt',
#  'waiting',
#  'phone',
#  'such',
#  'sorry',
#  'matter',
#  'coming',
#  'question',
#  'police',
#  'nobody',
#  'meet',
#  'hate',
#  'easy',
#  'lives',
#  'five',
#  'arent',
#  'reading',
#  'trouble',
#  'ate',
#  'table',
#  'eating',
#  'minutes',
#  'playing',
#  'nice',
#  'trying',
#  'started',
#  'might',
#  'important',
#  'students',
#  'office',
#  'finished',
#  'swim',
#  'having',
#  'times',
#  'son',
#  'woman',
#  'usually',
#  'station',
#  'felt',
#  'drive',
#  'needs',
#  'myself',
#  'japanese',
#  'story',
#  'far',
#  'decided',
#  'accident',
#  'small',
#  'pretty',
#  'hand',
#  'under',
#  'shouldnt',
#  'month',
#  'sick',
#  'ready',
#  'city',
#  'called',
#  'broke',
#  'tonight',
#  'fire',
#  'working',
#  'ran',
#  'goes',
#  'arrived',
#  'shoes',
#  'window',
#  'change',
#  'word',
#  'gone',
#  'hot',
#  'homework',
#  'fast',
#  'fun',
#  'eyes',
#  'stupid',
#  'music',
#  'mistake',
#  'game',
#  'anymore',
#  'town',
#  'quite',
#  'christmas',
#  'run',
#  'park',
#  'six',
#  'visit',
#  'rich',
#  'movie',
#  'language',
#  'baby',
#  'red',
#  'picture',
#  'fell',
#  'against',
#  'caught',
#  'afternoon',
#  'river',
#  'hair',
#  'finish',
#  'song',
#  'lived',
#  'tennis',
#  'advice',
#  'then',
#  'thank',
#  'spend',
#  'milk',
#  'face',
#  'breakfast',
#  'studying',
#  'sit',
#  'longer',
#  'interesting',
#  'cake',
#  'weve',
#  'through',
#  'summer',
#  'began',
#  'short',
#  'makes',
#  'kept',
#  'forget',
#  'close',
#  'war',
#  'number',
#  'comes',
#  'hotel',
#  'class',
#  'whos',
#  'smoking',
#  'older',
#  'listen',
#  'turned',
#  'cannot',
#  'present',
#  'later',
#  'along',
#  'making',
#  'living',
#  'fish',
#  'youd',
#  'killed',
#  'hospital',
#  'news',
#  'death',
#  'chance',
#  'bring',
#  'sometimes',
#  'hungry',
#  'free',
#  'dark',
#  'cut',
#  'tree',
#  'snow',
#  'computer',
#  'australia',
#  'kill',
#  'hour',
#  'became',
#  'age',
#  'wonder',
#  'gets',
#  'dream',
#  'box',
#  'mean',
#  'loves',
#  'large',
#  'clean',
#  'thinking',
#  'surprised',
#  'born',
#  'america',
#  'weather',
#  'watching',
#  'street',
#  'seem',
#  'saying',
#  'rather',
#  'questions',
#  'high',
#  'end',
#  'hands',
#  'camera',
#  'white',
#  'works',
#  'stopped',
#  'others',
#  'men',
#  'lie',
#  'full',
#  'forgot',
#  'birthday',
#  'wine',
#  'thinks',
#  'glad',
#  'bicycle',
#  'sat',
#  'light',
#  'dollars',
#  'dead',
#  'bit',
#  'speaking',
#  'moment',
#  'hasnt',
#  'die',
#  'student',
#  'daughter',
#  'company',
#  'hurry',
#  'taking',
#  'store',
#  'dogs',
#  'trust',
#  'tea',
#  'spent',
#  'secret',
#  'miss',
#  'helped',
#  'clothes',
#  'oclock',
#  'expensive',
#  'between',
#  'become',
#  'wrote',
#  'flowers',
#  'tokyo',
#  'near',
#  'careful',
#  'building',
#  'stand',
#  'possible',
#  'rest',
#  'order',
#  'whether',
#  'sing',
#  'canadian',
#  'beer',
#  'business',
#  'behind',
#  'plane',
#  'outside',
#  'key',
#  'hit',
#  'eaten',
#  'part',
#  'changed',
#  'wearing',
#  'sunday',
#  'quickly',
#  'four',
#  'worked',
#  'paper',
#  'glasses',
#  'famous',
#  'dress',
#  'girlfriend',
#  'break',
#  'whole',
#  'running',
#  'proud',
#  'lose',
#  'library',
#  'during',
#  'dictionary',
#  'trip',
#  'speaks',
#  'problems',
#  'asleep',
#  'wheres',
#  'touch',
#  'strange',
#  'stayed',
#  'real',
#  'piano',
#  'maybe',
#  'loved',
#  'drunk',
#  'dangerous',
#  'cats',
#  'advised',
#  'several',
#  'seven',
#  'reason',
#  'hold',
#  'herself',
#  'hat',
#  'catch',
#  'baseball',
#  'tall',
#  'takes',
#  'send',
#  'paid',
#  'interested',
#  'garden',
#  'crazy',
#  'black',
#  'bag',
#  'words',
#  'waited',
#  'thanks',
#  'quit',
#  'poor',
#  'pain',
#  'floor',
#  'different',
#  'blame',
#  'bank',
#  'yours',
#  'strong',
#  'raining',
#  'needed',
#  'ice',
#  'front',
#  'finally',
#  'exactly',
#  'cup',
#  'seemed',
#  'played',
#  'mistakes',
#  'anybody',
#  'opened',
#  'least',
#  'hide',
#  'cook',
#  'boys',
#  'air',
#  'weight',
#  'telephone',
#  'restaurant',
#  'missed',
#  'known',
#  'health',
#  'brought',
#  'agree',
#  'women',
#  'win',
#  'safe',
#  'probably',
#  'noise',
#  'movies',
#  'lucky',
#  'uncle',
#  'showed',
#  'sad',
#  'heart',
#  'danger',
#  'broken',
#  'worry',
#  'umbrella',
#  'thirty',
#  'smoke',
#  'pass',
#  'move',
#  'minute',
#  'walked',
#  'team',
#  'swimming',
#  'rules',
#  'head',
#  'enjoy',
#  'whose',
#  'shut',
#  'set',
#  'explain',
#  'shirt',
#  'radio',
#  'guitar',
#  'guess',
#  'evening',
#  'either',
#  'cost',
#  'concert',
#  'twice',
#  'somebody',
#  'side',
#  'return',
#  'paris',
#  'dance',
#  'sound',
#  'less',
#  'glass',
#  'feeling',
#  'choice',
#  'television',
#  'talked',
#  'prefer',
#  'ok',
#  'learned',
#  'completely',
#  'visited',
#  'situation',
#  'seeing',
#  'road',
#  'meat',
#  'london',
#  'hell',
#  'desk',
#  'cry',
#  'blue',
#  'apple',
#  'abroad',
#  'worried',
#  'wear',
#  'states',
#  'solve',
#  'lying',
#  'knife',
#  'husband',
#  'decision',
#  'arrive',
#  'united',
#  'singing',
#  'half',
#  'writing',
#  'sun',
#  'promise',
#  'point',
#  'opinion',
#  'mad',
#  'lake',
#  'hiding',
#  'forward',
#  'fishing',
#  'drinking',
#  'crying',
#  'animals',
#  'won',
#  'traffic',
#  'sitting',
#  'shouldve',
#  'second',
#  'passed',
#  'mountain',
#  'expect',
#  'drank',
#  'alive',
#  'wall',
#  'shopping',
#  'girls',
#  'airport',
#  'waste',
#  'sleeping',
#  'piece',
#  'medicine',
#  'learning',
#  'lawyer',
#  'closed',
#  'apples',
#  'accept',
#  'younger',
#  'ticket',
#  'spoke',
#  'patient',
#  'kitchen',
#  'invited',
#  'follow',
#  'fine',
#  'coat',
#  'beach',
#  'worse',
#  'serious',
#  'sent',
#  'promised',
#  'kiss',
#  'wash',
#  'vacation',
#  'sense',
#  'liked',
#  'leaving',
#  'hed',
#  'happens',
#  'figure',
#  'winter',
#  'weekend',
#  'walking',
#  'taken',
#  'soccer',
#  'seat',
#  'message',
#  'excuse',
#  'eggs',
#  'begin',
#  'werent',
#  'though',
#  'teach',
#  'ship',
#  'american',
#  'refused',
#  'offer',
#  'inside',
#  'happening',
#  'guy',
#  'fight',
#  'brothers',
#  'attention',
#  'address',
#  'travel',
#  'listening',
#  'impossible',
#  'hardly',
#  'driving',
#  'deal',
#  'china',
#  'cars',
#  'months',
#  'languages',
#  'kids',
#  'eats',
#  'case',
#  'carefully',
#  'arm',
#  'worth',
#  'tie',
#  'surprise',
#  'plans',
#  'pictures',
#  'expected',
#  'doubt',
#  'church',
#  'choose',
#  'chair',
#  'across',
#  'test',
#  'share',
#  'keys',
#  'itll',
#  'easily',
#  'cream',
#  'also',
#  'written',
#  'sounds',
#  'somewhere',
#  'smile',
#  'save',
#  'pen',
#  'horse',
#  'foreign',
#  'feed',
#  'failed',
#  'bridge',
#  'bread',
#  'boyfriend',
#  'taxi',
#  'smart',
#  'shot',
#  'pick',
#  'law',
#  'enemy',
#  'bird',
#  'wake',
#  'terrible',
#  'slowly',
#  'novel',
#  'mustve',
#  'lend',
#  'given',
#  'fat',
#  'clear',
#  'actually',
#  'warm',
#  'suddenly',
#  'stolen',
#  'sign',
#  'salt',
#  'perfect',
#  'machine',
#  'laughed',
#  'grandfather',
#  'funny',
#  'difference',
#  'college',
#  'boss',
#  'sugar',
#  'standing',
#  'heavy',
#  'grew',
#  'future',
#  'count',
#  'chinese',
#  'ball',
#  'york',
#  'wonderful',
#  'shop',
#  'sell',
#  'gun',
#  'foot',
#  'wallet',
#  'till',
#  'telling',
#  'success',
#  'price',
#  'moved',
#  'marry',
#  'leaves',
#  'france',
#  'fault',
#  'entered',
#  'bath',
#  'voice',
#  'stood',
#  'quiet',
#  'public',
#  'newspaper',
#  'nervous',
#  'fear',
#  'charge',
#  'watched',
#  'taught',
#  'guys',
#  'eight',
#  'aware',
#  'sky',
#  'sentence',
#  'ride',
#  ...]

# %%
class Decoder(tf.keras.layers.Layer):
    def __init__(self, text_processor, units):
        super(Decoder, self).__init__()
        self.text_processor = text_processor
        self.vocab_size = text_processor.vocabulary_size()
        self.word_to_id = tf.keras.layers.StringLookup(vocabulary=text_processor.get_vocabulary(), mask_token='', oov_token='[UNK]')
        self.id_to_word = tf.keras.layers.StringLookup(vocabulary=text_processor.get_vocabulary(), mask_token='', oov_token='[UNK]', invert=True)
        self.start_token = self.word_to_id('[START]')
        self.end_token = self.word_to_id('[END]')
        self.units = units
        self.embedding = tf.keras.layers.Embedding(self.vocab_size, units, mask_zero=True)
        self.rnn = tf.keras.layers.GRU(units, return_sequences=True, return_state=True, recurrent_initializer='glorot_uniform')
        self.attention = CrossAttention(units)
        self.output_layer = tf.keras.layers.Dense(self.vocab_size)
        
    def call(self, context, x, state=None, return_state=False):
        x = self.embedding(x)
        x, state = self.rnn(x, initial_state=state)
        x = self.attention(x, context)
        self.last_attention_weights = self.attention.last_attention_weights
        logits = self.output_layer(x)
        if return_state:
            return logits, state
        return logits
    
    def get_initial_state(self, context):
        batch_size = tf.shape(context)[0]
        start_tokens = tf.fill([batch_size, 1], self.start_token)
        done = tf.zeros([batch_size, 1], dtype=tf.bool)
        embedded = self.embedding(start_tokens)
        return start_tokens, done, self.rnn.get_initial_state(embedded)[0]  # [batch_size, units]
    
    def tokens_to_text(self, tokens):
        words = self.id_to_word(tokens)
        result = tf.strings.reduce_join(words, axis=-1, separator=' ')
        result = tf.strings.regex_replace(result, '^ *\[START\] *', '')
        result = tf.strings.regex_replace(result, ' *\[END\] *$', '')
        return result
    
    def get_next_token(self, context, next_token, done, state,temperature=0.0):
        logits, state = self(context, next_token, state=state, return_state=True)
        if temperature == 0.0:
            next_token = tf.argmax(logits, axis=-1)
        else:
            logits = logits[:, -1, :]/temperature
            next_token = tf.random.categorical(logits, num_samples=1)
        done |= (next_token == self.end_token)
        next_token = tf.where(done, tf.constant(0, dtype=tf.int64), next_token)
        return next_token, done, state

# %%
class Translator(tf.keras.Model):
    def __init__(self, units, context_text_processor, target_text_processor):
        super().__init__()
        self.encoder = Encoder(context_text_processor, units)
        self.decoder = Decoder(target_text_processor, units)
    
    def call(self, inputs):
        context, x = inputs
        context = self.encoder(context)
        logits = self.decoder(context, x)
        try:
            del logits._keras_mask
        except AttributeError:
            pass
        return logits
    
    def translate(self, texts, max_length=500, temperature=tf.constant(0.0)):
        context = self.encoder.convert_input(texts)
        next_token, done, state = self.decoder.get_initial_state(context)
        tokens = tf.TensorArray(tf.int64, size=1, dynamic_size=True)
        for t in tf.range(max_length):
            next_token, done, state = self.decoder.get_next_token(context, next_token, done, state, temperature)
            tokens = tokens.write(t, next_token)
            if tf.reduce_all(done):
                break
        tokens = tokens.stack()
        tokens = einops.rearrange(tokens, 't batch 1 -> batch t')
        text = self.decoder.tokens_to_text(tokens)
        return text

# %%
def masked_loss(y_true, y_pred):
    loss_fn = tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True, reduction='none')
    loss = loss_fn(y_true, y_pred)
    mask = tf.cast(y_true!=0, dtype=loss.dtype)
    loss *= mask
    return tf.reduce_sum(loss) / tf.reduce_sum(mask)

def masked_acc(y_true, y_pred):
    y_pred = tf.argmax(y_pred, axis=-1)
    y_pred = tf.cast(y_pred, y_true.dtype)
    match = tf.cast(y_true == y_pred, tf.float32)
    mask = tf.cast(y_true !=0 ,tf.float32)
    return tf.reduce_sum(match) / tf.reduce_sum(mask)

# %%
model = Translator(UNITS, context_text_processor, target_text_processor)
model.compile(optimizer='adam', loss=masked_loss, metrics=[masked_acc, masked_loss])
history = model.fit(train_ds.repeat(), epochs=100, steps_per_epoch=100, validation_data=val_ds, validation_steps=20, callbacks=[tf.keras.callbacks.EarlyStopping(patience=5)])
# Out:
# Epoch 1/100
# 100/100 [==============================] - 10s 55ms/step - loss: 4.6762 - masked_acc: 0.3038 - masked_loss: 4.6762 - val_loss: 3.7011 - val_masked_acc: 0.4109 - val_masked_loss: 3.7011
# Epoch 2/100
# 100/100 [==============================] - 4s 37ms/step - loss: 3.3200 - masked_acc: 0.4564 - masked_loss: 3.3200 - val_loss: 2.9685 - val_masked_acc: 0.5014 - val_masked_loss: 2.9685
# Epoch 3/100
# 100/100 [==============================] - 4s 38ms/step - loss: 2.7272 - masked_acc: 0.5345 - masked_loss: 2.7272 - val_loss: 2.5273 - val_masked_acc: 0.5633 - val_masked_loss: 2.5273
# Epoch 4/100
# 100/100 [==============================] - 4s 35ms/step - loss: 2.3292 - masked_acc: 0.5946 - masked_loss: 2.3292 - val_loss: 2.2206 - val_masked_acc: 0.5983 - val_masked_loss: 2.2206
# Epoch 5/100
# 100/100 [==============================] - 4s 36ms/step - loss: 2.0730 - masked_acc: 0.6256 - masked_loss: 2.0730 - val_loss: 2.0233 - val_masked_acc: 0.6335 - val_masked_loss: 2.0233
# Epoch 6/100
# 100/100 [==============================] - 4s 36ms/step - loss: 1.8813 - masked_acc: 0.6534 - masked_loss: 1.8813 - val_loss: 1.8809 - val_masked_acc: 0.6526 - val_masked_loss: 1.8809
# Epoch 7/100
# 100/100 [==============================] - 4s 36ms/step - loss: 1.7847 - masked_acc: 0.6694 - masked_loss: 1.7847 - val_loss: 1.6754 - val_masked_acc: 0.6811 - val_masked_loss: 1.6754
# Epoch 8/100
# 100/100 [==============================] - 4s 37ms/step - loss: 1.6658 - masked_acc: 0.6879 - masked_loss: 1.6658 - val_loss: 1.6070 - val_masked_acc: 0.6881 - val_masked_loss: 1.6070
# Epoch 9/100
# 100/100 [==============================] - 4s 36ms/step - loss: 1.5885 - masked_acc: 0.6970 - masked_loss: 1.5885 - val_loss: 1.5669 - val_masked_acc: 0.7019 - val_masked_loss: 1.5669
# Epoch 10/100
# 100/100 [==============================] - 4s 36ms/step - loss: 1.5539 - masked_acc: 0.6997 - masked_loss: 1.5539 - val_loss: 1.5534 - val_masked_acc: 0.6954 - val_masked_loss: 1.5534
# Epoch 11/100
# 100/100 [==============================] - 4s 36ms/step - loss: 1.4773 - masked_acc: 0.7128 - masked_loss: 1.4773 - val_loss: 1.4312 - val_masked_acc: 0.7130 - val_masked_loss: 1.4312
# Epoch 12/100
# 100/100 [==============================] - 4s 38ms/step - loss: 1.4822 - masked_acc: 0.7108 - masked_loss: 1.4822 - val_loss: 1.4574 - val_masked_acc: 0.7116 - val_masked_loss: 1.4574
# Epoch 13/100
# 100/100 [==============================] - 4s 37ms/step - loss: 1.3966 - masked_acc: 0.7221 - masked_loss: 1.3966 - val_loss: 1.4209 - val_masked_acc: 0.7150 - val_masked_loss: 1.4209
# Epoch 14/100
# 100/100 [==============================] - 3s 29ms/step - loss: 1.3716 - masked_acc: 0.7272 - masked_loss: 1.3716 - val_loss: 1.3061 - val_masked_acc: 0.7351 - val_masked_loss: 1.3061
# Epoch 15/100
# 100/100 [==============================] - 4s 36ms/step - loss: 1.3147 - masked_acc: 0.7322 - masked_loss: 1.3080 - val_loss: 1.4580 - val_masked_acc: 0.7085 - val_masked_loss: 1.4580
# Epoch 16/100
# 100/100 [==============================] - 4s 37ms/step - loss: 1.1146 - masked_acc: 0.7574 - masked_loss: 1.1146 - val_loss: 1.3381 - val_masked_acc: 0.7337 - val_masked_loss: 1.3381
# Epoch 17/100
# 100/100 [==============================] - 4s 36ms/step - loss: 1.1198 - masked_acc: 0.7573 - masked_loss: 1.1198 - val_loss: 1.3561 - val_masked_acc: 0.7312 - val_masked_loss: 1.3561
# Epoch 18/100
# 100/100 [==============================] - 4s 36ms/step - loss: 1.1265 - masked_acc: 0.7554 - masked_loss: 1.1265 - val_loss: 1.3049 - val_masked_acc: 0.7347 - val_masked_loss: 1.3049
# Epoch 19/100
# 100/100 [==============================] - 4s 36ms/step - loss: 1.1245 - masked_acc: 0.7578 - masked_loss: 1.1245 - val_loss: 1.2984 - val_masked_acc: 0.7344 - val_masked_loss: 1.2984
# Epoch 20/100
# 100/100 [==============================] - 4s 36ms/step - loss: 1.1069 - masked_acc: 0.7619 - masked_loss: 1.1069 - val_loss: 1.3187 - val_masked_acc: 0.7349 - val_masked_loss: 1.3187
# Epoch 21/100
# 100/100 [==============================] - 4s 38ms/step - loss: 1.1134 - masked_acc: 0.7595 - masked_loss: 1.1134 - val_loss: 1.3097 - val_masked_acc: 0.7326 - val_masked_loss: 1.3097
# Epoch 22/100
# 100/100 [==============================] - 4s 36ms/step - loss: 1.1155 - masked_acc: 0.7611 - masked_loss: 1.1155 - val_loss: 1.3309 - val_masked_acc: 0.7296 - val_masked_loss: 1.3309
# Epoch 23/100
# 100/100 [==============================] - 4s 37ms/step - loss: 1.0940 - masked_acc: 0.7643 - masked_loss: 1.0940 - val_loss: 1.2995 - val_masked_acc: 0.7353 - val_masked_loss: 1.2995
# Epoch 24/100
# 100/100 [==============================] - 4s 37ms/step - loss: 1.0971 - masked_acc: 0.7656 - masked_loss: 1.0971 - val_loss: 1.2503 - val_masked_acc: 0.7482 - val_masked_loss: 1.2503
# Epoch 25/100
# 100/100 [==============================] - 4s 37ms/step - loss: 1.0956 - masked_acc: 0.7629 - masked_loss: 1.0956 - val_loss: 1.2452 - val_masked_acc: 0.7484 - val_masked_loss: 1.2452
# Epoch 26/100
# 100/100 [==============================] - 4s 37ms/step - loss: 1.0942 - masked_acc: 0.7638 - masked_loss: 1.0942 - val_loss: 1.2109 - val_masked_acc: 0.7550 - val_masked_loss: 1.2109
# Epoch 27/100
# 100/100 [==============================] - 4s 36ms/step - loss: 1.0664 - masked_acc: 0.7698 - masked_loss: 1.0664 - val_loss: 1.1834 - val_masked_acc: 0.7516 - val_masked_loss: 1.1834
# Epoch 28/100
# 100/100 [==============================] - 4s 36ms/step - loss: 1.0493 - masked_acc: 0.7720 - masked_loss: 1.0493 - val_loss: 1.1830 - val_masked_acc: 0.7516 - val_masked_loss: 1.1830
# Epoch 29/100
# 100/100 [==============================] - 4s 36ms/step - loss: 1.0782 - masked_acc: 0.7686 - masked_loss: 1.0782 - val_loss: 1.1937 - val_masked_acc: 0.7523 - val_masked_loss: 1.1937
# Epoch 30/100
# 100/100 [==============================] - 3s 33ms/step - loss: 1.0156 - masked_acc: 0.7778 - masked_loss: 1.0126 - val_loss: 1.1963 - val_masked_acc: 0.7546 - val_masked_loss: 1.1963
# Epoch 31/100
# 100/100 [==============================] - 3s 34ms/step - loss: 0.8015 - masked_acc: 0.8108 - masked_loss: 0.8015 - val_loss: 1.2171 - val_masked_acc: 0.7465 - val_masked_loss: 1.2171
# Epoch 32/100
# 100/100 [==============================] - 4s 37ms/step - loss: 0.8326 - masked_acc: 0.8038 - masked_loss: 0.8326 - val_loss: 1.2087 - val_masked_acc: 0.7550 - val_masked_loss: 1.2087
# Epoch 33/100
# 100/100 [==============================] - 4s 37ms/step - loss: 0.8469 - masked_acc: 0.7994 - masked_loss: 0.8469 - val_loss: 1.2172 - val_masked_acc: 0.7532 - val_masked_loss: 1.2172

# %%
inputs = [
    'Hace mucho frio aqui.', # "It's really cold here."
    'Esta es mi vida.', # "This is my life."
    'Su cuarto es un desastre.' # "His room is a mess"
]
result = model.translate(inputs)
print(result)
# Out:
# tf.Tensor(
# [b'its very cold here .  ' b'this is my life .  '
#  b'his room is a disaster . '], shape=(3,), dtype=string)
