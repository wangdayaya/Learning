# %%
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt

print(tf.__version__)
# Out:
# 2.10.0

# %%
fasion_mnist = tf.keras.datasets.fashion_mnist
(train_images, train_labels), (test_images, test_labels) = fasion_mnist.load_data()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/train-labels-idx1-ubyte.gz
# 29515/29515 [==============================] - 0s 2us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/train-images-idx3-ubyte.gz
# 26421880/26421880 [==============================] - 3s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/t10k-labels-idx1-ubyte.gz
# 5148/5148 [==============================] - 0s 0s/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/t10k-images-idx3-ubyte.gz
# 4422102/4422102 [==============================] - 1s 0us/step

# %%
class_names = ['T-shirt/top', 'Trouser', 'Pullover', 'Dress', 'Coat', 'Sandal', 'Shirt', 'Sneaker', 'Bag', 'Ankle boot']

# %%
plt.figure()
plt.imshow(train_images[0])
plt.show()

# %%
plt.figure(figsize=(10,12))
for i in range(16):
    plt.subplot(4,4,i+1)
    plt.imshow(train_images[i])
    plt.xlabel(class_names[train_labels[i]])
plt.show()

# %%
model = tf.keras.Sequential([
    tf.keras.layers.Flatten(input_shape=(28,28)),
    tf.keras.layers.Dense(128, activation='relu'),
    tf.keras.layers.Dense(10)
])
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  flatten (Flatten)           (None, 784)               0
#
#  dense (Dense)               (None, 128)               100480
#
#  dense_1 (Dense)             (None, 10)                1290
#
# =================================================================
# Total params: 101,770
# Trainable params: 101,770
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(optimizer='adam', loss = tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True), metrics=["accuracy"])

# %%
model.fit(train_images, train_labels, epochs=10)
# Out:
# Epoch 1/10
# 1875/1875 [==============================] - 5s 2ms/step - loss: 3.5188 - accuracy: 0.6766
# Epoch 2/10
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.6827 - accuracy: 0.7593
# Epoch 3/10
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.5854 - accuracy: 0.7935
# Epoch 4/10
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.5346 - accuracy: 0.8127
# Epoch 5/10
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.5175 - accuracy: 0.8231
# Epoch 6/10
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.5023 - accuracy: 0.8267
# Epoch 7/10
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.4923 - accuracy: 0.8328
# Epoch 8/10
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.4816 - accuracy: 0.8361
# Epoch 9/10
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.4829 - accuracy: 0.8374
# Epoch 10/10
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.4691 - accuracy: 0.8417

# %%
test_loss, test_acc = model.evaluate(test_images, test_labels, verbose=2)
print("test accuracy:", test_acc)
# Out:
# 313/313 - 0s - loss: 0.5801 - accuracy: 0.8030 - 452ms/epoch - 1ms/step
# test accuracy: 0.8029999732971191
